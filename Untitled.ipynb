# %% [markdown]
# # Read .doc file and clean the data and create a dataframe

# %%
from gender_predictor import GenderPredictor
gp = GenderPredictor()
gp.train_and_test()
# Out:
# import complete
# 32,031 male names
# 56,347 female names
# classifier accuracy: 96.78%

# %%
import docx
import pprint
import pandas as pd
import requests
import json
import seaborn as sns
from genderize import Genderize
# %matplotlib inline

file_name = 'Streetbook_2018-08-15.docx'
boston_street_zipcodes = 'boston_street_zipcodes.csv'

##################################################################################################
#list of words t obe removed from street names 
words_to_be_removed = ['Street',',', 'Road','Place','Square',';',
                          'Boulevard','Highway','Avenue','Alley']

############################################################################################

def get_zipcode_latitude_longitude_dataframe(fileName):
    return pd.read_csv(fileName,  converters={i: str for i in range(100)})
##########################################################################################

def clean_street_names(street_name, words_to_be_removed):
    for word in words_to_be_removed:
        street_name = street_name.replace(word, '')
    return street_name

#################################################################################

def create_request_url_string(first_name, last_name):
    prefix = 'https://api.namsor.com/onomastics/api/json/gender/'
    return prefix + first_name + '/' + last_name + '/us'

######################################################################################

def get_gender(street_name):
    first_name = 'null'
    last_name = 'null'
    splited_word = street_name.split()
    if len(splited_word) >= 1:
        first_name = splited_word[0]
    if len(splited_word) >= 2:
        last_name = splited_word[1]
    response = requests.get(create_request_url_string(first_name, last_name))
    response_json = response.json()
    #print(response.json())
    return response_json['gender']
    
#############################################################################################

#second api
def getGender(street_name):
    first_name = 'null'
    splited_word = street_name.split()
    if len(splited_word) >= 1:
        first_name = splited_word[0]
    gender = gp.classify(first_name)
    return gender

#############################################################################################

def get_datadframe_from_file(fileName, limit, words_to_be_removed):
    doc = docx.Document(fileName)
    dataDict = {}
    rowIndex = 1
    for p in doc.paragraphs:
    #validating paragraphs
        if p.text != '' and len(p.text) > 5:
            for run in p.runs:
                run.text = run.text.strip()
                # I have set the limit to 100 since it is kind of slow right now making api calls 
                if run.bold and run.text != "" and run.text != "*" and run.text != "Note;" and rowIndex <= limit:
                    street_name = clean_street_names(run.text, words_to_be_removed)
                    gender = get_gender(street_name)
                    gender2 = getGender(street_name)
                    dataDict[rowIndex] = [run.text,street_name,gender,gender2]
                    rowIndex += 1
    return pd.DataFrame.from_dict(dataDict, orient='index', columns=['full_name','street-name','gender','gender2'])  
    
###############################################################################################

def get_zipcode_dict_from_file(filename):
    doc = docx.Document(filename)
    zipCodeDict = {}
    rowIndex = 0
    for p in doc.paragraphs:
        #validating paragraphs
        if p.text != '' and len(p.text) > 5:
            for run in p.runs:
                run.text = run.text.strip()
                # if paragraph starts with a bold name, it means this is a new paragraph containing info about a new street
                if run.bold and run.text != "" and run.text != "*" and run.text != "Note;":
                    rowIndex += 1
                    zipCodeDict[rowIndex] = []
                    break
            #if constainsZipInfo:
            paragraph_words = p.text.split()
            #get last word as the zip code
            zipcode = paragraph_words[len(paragraph_words) - 1]
            zipCodeDict[rowIndex].append(zipcode)
    return zipCodeDict

#####################################################################################################

def clean_zipcode_dict(zipcode_dict):
    for rowIndex_key, value_list in zipcode_dict.items():
        zipcode_list = ""
        for elem in value_list[:-1]:
            elem = elem.strip()
            if elem.isdigit():
                zipcode_list += elem + "-"
        if value_list[-1].isdigit():
            zipcode_list += value_list[-1]
        #based on the number of street segments with this name
        rank = len(zipcode_list.split("-"))
        zipcodes = remove_duplicate_from_zipcode_list(zipcode_list)
        zipcode_dict[rowIndex_key] = [zipcodes, rank]
    return zipcode_dict

#######################################################################################################

def remove_duplicate_from_zipcode_list(zipcode_list):
    zipcodes = ""
    zipcode_list = zipcode_list.split("-")
    zipcode_list = list(set(zipcode_list))
    for zipcode in zipcode_list[:-1]:
        zipcodes += zipcode + "-" 
    zipcodes += zipcode_list[-1]  
    return zipcodes

#######################################################################################

def create_zipcode_df(filename):
    zipcode_dict = get_zipcode_dict_from_file(filename)
    zipcode_dict = clean_zipcode_dict(zipcode_dict)
    return pd.DataFrame.from_dict(zipcode_dict, orient='index', columns=['zipcode', 'rank']) 

#######################################################################################################

def splitDataFrameList(df,target_column,separator):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df

####################################################################################
zipcode_df = create_zipcode_df(file_name)
zipcode_df = zipcode_df.head(5000)
df = get_datadframe_from_file(file_name, 5000, words_to_be_removed)
frames = [df, zipcode_df]
main_df = pd.concat(frames,axis=1, sort=False)
main_df_split_by_zipcode = splitDataFrameList(main_df,'zipcode',"-")
zipcode_latitude_longitude_df = get_zipcode_latitude_longitude_dataframe(boston_street_zipcodes)
main_df_merged_with_geo = main_df_split_by_zipcode.merge(zipcode_latitude_longitude_df, left_on='zipcode', right_on='ZIP', how='inner')
main_df_merged_with_geo = main_df_merged_with_geo.sort_values(by=['full_name'])
main_df_merged_with_geo
# Out:
#                full_name   gender gender2  rank        street-name zipcode  \
# 0              A Street,  unknown       F     1                 A    02136
# 375            A Street,  unknown       F     2                 A    02127
# 322            A Street,  unknown       F     2                 A    02210
# 585        Abbot Street,     male       M     2             Abbot    02124
# 964   Abbotsford Street,  unknown       M     1        Abbotsford    02121
# 1110          Abby Road,   female       M     1              Abby    02135
# 1350    Aberdeen Street,   female       M     1          Aberdeen    02215
# 1406        Acacia Road,   female       F     1            Acacia    02132
# 1750       Academic Way,   female       M     1       Academic Way   02134
# 1890      Academy Court,  unknown       F     1      Academy Court   02119
# 1111  Academy Hill Road,  unknown       F     3      Academy Hill    02135
# 1891       Academy Road,     male       F     1           Academy    02119
# 1892    Academy Terrace,  unknown       F     1    Academy Terrace   02119
# 376       Acadia Street,   female       F     1            Acadia    02127
# 2193      Achorn Circle,  unknown       M     1      Achorn Circle   02130
# 2194       Ackley Place,     male       F     1            Ackley    02130
# 2522       Acorn Street,  unknown       M     1             Acorn    02108
# 1          Acton Street,     male       M     1             Acton    02136
# 2584         Ada Street,   female       F     1               Ada    02131
# 1112         Adair Road,  unknown       M     1             Adair    02135
# 377         Adams Place,     male       M     1             Adams    02127
# 2          Adams Street,     male       M     1             Adams    02136
# 2874       Adams Street,     male       M     2             Adams    02129
# 3095       Adams Street,     male       M    15             Adams    02122
# 586        Adams Street,     male       M    15             Adams    02124
# 1893       Adams Street,     male       M     2             Adams    02119
# 3096      Adams Terrace,     male       M     1      Adams Terrace   02122
# 1751     Adamson Street,     male       M     1           Adamson    02134
# 587      Adanac Terrace,     male       M     1     Adanac Terrace   02124
# 1407     Addington Road,   female       M     1         Addington    02132
# ...                  ...      ...     ...   ...                ...     ...
# 1747     Wolcott Street,     male       M     1           Wolcott    02132
# 319        Wolfe Street,     male       M     5             Wolfe    02136
# 3994       Wolfe Street,     male       M     5             Wolfe    02126
# 3093  Wollaston Terrace,     male       M     1  Wollaston Terrace   02129
# 1748        Wood Avenue,     male       M     2              Wood    02132
# 2189        Wood Street,     male       M     1              Wood    02119
# 3995       Woodard Road,     male       M     1           Woodard    02126
# 2517    Woodbine Street,     male       F     1          Woodbine    02130
# 1749    Woodbole Avenue,     male       F     1          Woodbole    02132
# 3766    Woodbourne Road,     male       F     2        Woodbourne    02125
# 3996     Woodbrier Road,     male       M     1         Woodbrier    02126
# 3312   Woodcliff Street,     male       M     1         Woodcliff    02122
# 3767    Wooddale Avenue,     male       F     1          Wooddale    02125
# 3997   Woodfield Street,     male       M     1         Woodfield    02126
# 320     Woodford Street,     male       M     1          Woodford    02136
# 3998    Woodgate Street,     male       F     2          Woodgate    02126
# 321       Woodglen Road,     male       M     1          Woodglen    02136
# 2518   Woodhaven Street,     male       M     1         Woodhaven    02130
# 2519     Woodland Place,     male       M     1          Woodland    02130
# 3768      Woodland Road,     male       M     2          Woodland    02125
# 2520   Woodledge Street,     male       M     1         Woodledge    02130
# 3999     Woodley Avenue,     male       F     1           Woodley    02126
# 1349     Woodman Street,     male       M     1           Woodman    02135
# 963     Woodmere Street,     male       M     5          Woodmere    02124
# 4000    Woodmont Street,     male       M     1          Woodmont    02126
# 3094     Woodrow Avenue,     male       M     1           Woodrow    02129
# 2521        Woodruff Way     male       M     2       Woodruff Way   02130
# 2190    Woodside Avenue,  unknown       F     1          Woodside    02119
# 2191   Woodstock Avenue,     male       M     2         Woodstock    02119
# 2192      Woodville Park  unknown       F     1     Woodville Park   02119
#
#         ZIP        LAT          LNG
# 0     02136  42.255083   -71.129220
# 375   02127  42.334992   -71.039093
# 322   02210  42.347472   -71.039271
# 585   02124  42.285805   -71.070571
# 964   02121  42.306267   -71.085897
# 1110  02135  42.349688   -71.153964
# 1350  02215  42.347635   -71.103082
# 1406  02132  42.280455   -71.162017
# 1750  02134  42.358016   -71.128608
# 1890  02119  42.324029   -71.085017
# 1111  02135  42.349688   -71.153964
# 1891  02119  42.324029   -71.085017
# 1892  02119  42.324029   -71.085017
# 376   02127  42.334992   -71.039093
# 2193  02130  42.309174   -71.113835
# 2194  02130  42.309174   -71.113835
# 2522  02108  42.357768   -71.064858
# 1     02136  42.255083   -71.129220
# 2584  02131  42.284333   -71.126228
# 1112  02135  42.349688   -71.153964
# 377   02127  42.334992   -71.039093
# 2     02136  42.255083   -71.129220
# 2874  02129  42.379657   -71.061487
# 3095  02122  42.291413   -71.042158
# 586   02124  42.285805   -71.070571
# 1893  02119  42.324029   -71.085017
# 3096  02122  42.291413   -71.042158
# 1751  02134  42.358016   -71.128608
# 587   02124  42.285805   -71.070571
# 1407  02132  42.280455   -71.162017
# ...     ...        ...          ...
# 1747  02132  42.280455   -71.162017
# 319   02136  42.255083   -71.129220
# 3994  02126  42.274227   -71.097423
# 3093  02129  42.379657   -71.061487
# 1748  02132  42.280455   -71.162017
# 2189  02119  42.324029   -71.085017
# 3995  02126  42.274227   -71.097423
# 2517  02130  42.309174   -71.113835
# 1749  02132  42.280455   -71.162017
# 3766  02125  42.315682   -71.055555
# 3996  02126  42.274227   -71.097423
# 3312  02122  42.291413   -71.042158
# 3767  02125  42.315682   -71.055555
# 3997  02126  42.274227   -71.097423
# 320   02136  42.255083   -71.129220
# 3998  02126  42.274227   -71.097423
# 321   02136  42.255083   -71.129220
# 2518  02130  42.309174   -71.113835
# 2519  02130  42.309174   -71.113835
# 3768  02125  42.315682   -71.055555
# 2520  02130  42.309174   -71.113835
# 3999  02126  42.274227   -71.097423
# 1349  02135  42.349688   -71.153964
# 963   02124  42.285805   -71.070571
# 4000  02126  42.274227   -71.097423
# 3094  02129  42.379657   -71.061487
# 2521  02130  42.309174   -71.113835
# 2190  02119  42.324029   -71.085017
# 2191  02119  42.324029   -71.085017
# 2192  02119  42.324029   -71.085017
#
# [4719 rows x 9 columns]

# %% [markdown]
# # Show the distribution in a scatter plot
# #### Size of cricles correponds to the size of the street which is infered from the number of segments in the original street map

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn import preprocessing
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns


#plt.style.use('ggplot')
min_max_scaler = preprocessing.MinMaxScaler()

def create_patches(colors, real_labels):
    """this function takes a list of colors and a list 
    of real names as the input. length of these two lists 
    must be the same.it create corresponding patches for plot legend
    """
    patches = []
    for i in range (0, len(real_labels)):
        patch = mpatches.Patch(color=colors[i], label= real_labels[i])
        patches.append(patch)
    return patches

data = main_df_merged_with_geo[['LAT','LNG','gender','gender2','rank']]
data['LAT'] = min_max_scaler.fit_transform(data['LAT'].values.reshape(-1,1))
data['LNG'] = min_max_scaler.fit_transform(data['LNG'].values.reshape(-1,1))

#data[["LAT", "LNG", "rank"]] = data[["LAT", "LNG","rank"]].apply(pd.to_numeric)
genders = data['gender']
colors = ['red','purple','green']
labels = []
for elem in data['gender'].tolist():
    if elem == 'male':
        labels.append('red')
    elif elem == 'female':
        labels.append('purple')
    elif elem == "unknown":
        labels.append('green')

colors = ("red", "purple", "green")
fig, ax = plt.subplots()
scatter_plt = ax.scatter(data['LAT'], data['LNG'], c=labels, cmap=matplotlib.colors.ListedColormap(colors), vmin=0, vmax=2,
                        edgecolor = 'black', s=data["rank"]*50)
#fig.set_size_inches(6.5, 6.5)
ax.set_xlabel('latitude')
ax.set_ylabel('longitude')
ax.set_title('Boston Street Names Gender Distribution')
plt.legend(handles=create_patches(colors, ['male','female','unknown']))
plt.show()

# %%
#data[["LAT", "LNG", "rank"]] = data[["LAT", "LNG","rank"]].apply(pd.to_numeric)
genders = data['gender2']
colors = ['red','purple']
labels = []
for elem in data['gender2'].tolist():
    if elem == 'M':
        labels.append('red')
    elif elem == 'F':
        labels.append('purple')

colors = ("red", "purple")
fig, ax = plt.subplots()
scatter_plt = ax.scatter(data['LAT'], data['LNG'], c=labels, cmap=matplotlib.colors.ListedColormap(colors), vmin=0, vmax=2,
                        edgecolor = 'black', s=data["rank"]*50)
#fig.set_size_inches(6.5, 6.5)
ax.set_xlabel('latitude')
ax.set_ylabel('longitude')
ax.set_title('Boston Street Names Gender Distribution')
plt.legend(handles=create_patches(colors, ['M','F']))
plt.show()

# %% [markdown]
# # Count total number of unknowns, male and female and plot bar

# %%
df['gender'].value_counts().plot(kind='bar')

def get_counts_for_gender(df):
    groupedByGender = df.groupby(['gender'], sort=False)['count'].sum().to_frame()
    return groupedByGender.to_dict()

df['count'] = 1
pprint.pprint(get_counts_for_gender(df), width=1)

groupedByStreetNames = df.groupby(['street-name'], sort=False)['count'].sum().to_frame()
groupedByStreetNames = groupedByStreetNames.sort_values('count', ascending=False)
groupedByStreetNames = groupedByStreetNames.merge(df, left_on='street-name', right_on='street-name')
#print(groupedByStreetNames)
#print(df)
#df
# Out:
# {'count': {'female': 987,
#            'male': 3300,
#            'unknown': 713}}

# %%
df['gender2'].value_counts().plot(kind='bar')

def get_counts_for_gender(df):
    groupedByGender = df.groupby(['gender2'], sort=False)['count'].sum().to_frame()
    return groupedByGender.to_dict()

df['count'] = 1
pprint.pprint(get_counts_for_gender(df), width=1)
# Out:
# {'count': {'F': 1073,
#            'M': 3927}}

# %% [markdown]
#  # Find the most repetetive names

# %%
groupedByStreetNames = df.groupby(['street-name'], sort=False)['count'].sum().to_frame()
groupedByStreetNames = groupedByStreetNames.sort_values('count', ascending=False)
groupedByStreetNames
# Out:
#                              count
# street-name
# Warren                          10
# Everett                         10
# Harvard                         10
# Chestnut                         9
# Webster                          8
# Mt. Vernon                       8
# Franklin                         8
# Cedar                            7
# Lexington                        7
# Maple                            6
# Lincoln                          6
# Washington                       6
# Putnam                           6
# Jackson                          6
# Walnut                           6
# Park                             6
# Gardner                          6
# Oak                              6
# Arlington                        5
# Union                            5
# Milton                           5
# Sherman                          5
# School                           5
# Winthrop                         5
# Tremont                          5
# Pine                             5
# Sumner                           5
# Church                           5
# Grove                            5
# Charles                          5
# ...                            ...
# Francis J. Murray Way            1
# Francis J. Mitchell Bridge       1
# Foodmart                         1
# Forbes                           1
# Ford                             1
# Fordham Court                    1
# Fordham                          1
# Forest Hills Entrance Drive      1
# Forestvale                       1
# Forsyth Park                     1
# Forsyth                          1
# Forsyth Way                      1
# Fort                             1
# Fort  Terrace                    1
# Fossdale                         1
# Foster Court                     1
# Foster Terrace                   1
# Fottler                          1
# Foundry                          1
# Fourth                           1
# Fourth                           1
# Fowle                            1
# Fowler                           1
# Fox                              1
# Fox Point                        1
# Francesca                        1
# Francis                          1
# Francis B. Johnson               1
# Francis G. Hanlon                1
# Woodville Park                   1
#
# [4304 rows x 1 columns]

# %% [markdown]
# # Plot bar chart for 30 most repetttive names

# %%
top_names = groupedByStreetNames.head(30)
top_names = df.merge(top_names, left_on='street-name', right_on='street-name')
top_male_names = top_names[top_names['gender'] == 'male']
top_male_names['street-name'].value_counts().plot(kind='bar')
plt.show()

# %%
top_male_names = top_names[top_names['gender2'] == 'M']
top_male_names['street-name'].value_counts().plot(kind='bar')
plt.show()

# %%
top_male_names = top_male_names.sort_values(by=['count_y'], ascending=False)
top_male_names
# Out:
#              full_name street-name   gender gender2  count_x  count_y
# 69     Harvard Street,    Harvard      male       M        1       10
# 36     Everett Street,    Everett      male       M        1       10
# 61     Harvard Avenue,    Harvard      male       M        1       10
# 60     Harvard Avenue,    Harvard      male       M        1       10
# 164     Warren Avenue,     Warren      male       M        1       10
# 31     Everett Avenue,    Everett      male       M        1       10
# 32      Everett Place,    Everett      male       M        1       10
# 33     Everett Square,    Everett      male       M        1       10
# 34     Everett Square,    Everett      male       M        1       10
# 35     Everett Square,    Everett      male       M        1       10
# 37     Everett Street,    Everett      male       M        1       10
# 63      Harvard Place,    Harvard      male       M        1       10
# 38     Everett Street,    Everett      male       M        1       10
# 39     Everett Street,    Everett      male       M        1       10
# 40     Everett Street,    Everett      male       M        1       10
# 170     Warren Street,     Warren      male       M        1       10
# 169     Warren Street,     Warren      male       M        1       10
# 168     Warren Square,     Warren      male       M        1       10
# 167     Warren Square,     Warren      male       M        1       10
# 166     Warren Square,     Warren      male       M        1       10
# 62     Harvard Avenue,    Harvard      male       M        1       10
# 165      Warren Place,     Warren      male       M        1       10
# 67     Harvard Street,    Harvard      male       M        1       10
# 64      Harvard Place,    Harvard      male       M        1       10
# 162     Warren Avenue,     Warren      male       M        1       10
# 171     Warren Street,     Warren      male       M        1       10
# 68     Harvard Street,    Harvard      male       M        1       10
# 163     Warren Avenue,     Warren      male       M        1       10
# 66     Harvard Square,    Harvard      male       M        1       10
# 65      Harvard Place,    Harvard      male       M        1       10
# ..                 ...         ...      ...     ...      ...      ...
# 16     Charles Street,    Charles      male       M        1        5
# 99      Milton Street,     Milton      male       M        1        5
# 15     Charles Street,    Charles      male       M        1        5
# 14     Charles Street,    Charles      male       M        1        5
# 13     Charles Street,    Charles      male       M        1        5
# 12       Charles Road,    Charles      male       M        1        5
# 4    Arlington Street,  Arlington      male       M        1        5
# 3    Arlington Street,  Arlington      male       M        1        5
# 2    Arlington Street,  Arlington      male       M        1        5
# 1    Arlington Square,  Arlington      male       M        1        5
# 131     School Street,     School   unknown       M        1        5
# 149    Tremont Street,    Tremont      male       M        1        5
# 141     Sumner Avenue,     Sumner      male       M        1        5
# 148    Tremont Street,    Tremont      male       M        1        5
# 147     Tremont Place,    Tremont      male       M        1        5
# 146     Tremont Place,    Tremont      male       M        1        5
# 145     Sumner Street,     Sumner      male       M        1        5
# 144     Sumner Street,     Sumner      male       M        1        5
# 143     Sumner Square,     Sumner      male       M        1        5
# 142      Sumner Place,     Sumner      male       M        1        5
# 140    Sherman Street,    Sherman      male       M        1        5
# 132     School Street,     School   unknown       M        1        5
# 139    Sherman Street,    Sherman      male       M        1        5
# 138    Sherman Street,    Sherman      male       M        1        5
# 137    Sherman Square,    Sherman      male       M        1        5
# 136      Sherman Road,    Sherman      male       M        1        5
# 135     School Street,     School   unknown       M        1        5
# 134     School Street,     School   unknown       M        1        5
# 133     School Street,     School   unknown       M        1        5
# 190   Winthrop Street,   Winthrop      male       M        1        5
#
# [175 rows x 6 columns]

# %%
import random
number_of_colors = 20

colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]

top_hundred_names = groupedByStreetNames.head(20)
top_hundred_names.rename_axis("street-name")

label_map = {}
label = 0
for index, row in top_hundred_names.iterrows():
    row_name_splited = row.name.split(',')
    label_map[row_name_splited[0]]= label
    label += 1
    
'''labels = []
for i in range(0,241):
    labels.append(i)
'''    
top_hundred_names = top_hundred_names.merge(main_df_merged_with_geo, left_on='street-name', right_on='street-name')
top_hundred_names['LAT'] = min_max_scaler.fit_transform(top_hundred_names['LAT'].values.reshape(-1,1))
top_hundred_names['LNG'] = min_max_scaler.fit_transform(top_hundred_names['LNG'].values.reshape(-1,1))

labels = []
for index, row in top_hundred_names.iterrows():
     labels.append(label_map[row['street-name']])

#print(label_map)
fig, ax = plt.subplots()
scatter_plt = ax.scatter(top_hundred_names['LAT'], top_hundred_names['LNG'], c=labels,cmap=matplotlib.colors.ListedColormap(colors), edgecolor = 'black', s=100)
plt.legend(handles=create_patches(colors, list(set(top_hundred_names['street-name']))), loc=2)
#top_hundred_names

# %% [markdown]
# # Find street candidates to be renamed
# #### For renaming streets we need to consider a combination of factors like the global ferequency of the name across Boston erea, distribution rank which is defined by the number of clusters in which there streets with that name given a clustering factor, and concentration-rank which is the local frequency of the name in each cluster.
# #### Other factors like size of the street are implictily considered in this approach given the fact that diffrent street sesgments for a name(with either or same zipcode) in the original datasets are considered as separate records in data set.

# %%
from sklearn import preprocessing
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
import warnings
warnings.filterwarnings("ignore")


########################################################################################

def get_top_names_in_cluster(cluster_num, labels, dataframe):
    top_names = []
    count_dict = {}
    labels_index = 0
    for index, row in dataframe.iterrows():
        if labels[labels_index] == cluster_num:
            if row['street-name'] in count_dict:
                count_dict[row['street-name']] += 1
            else:
                count_dict[row['street-name']] = 1
        labels_index += 1
    sorted_count_dict = sorted(count_dict, key=count_dict.get, reverse=True)
    for elem in sorted_count_dict:
        value = {}
        value[elem] = count_dict[elem]
        top_names.append(value)
    return top_names

#######################################################################################

def get_real_labels_for_clusters(labels, dataframe, num_clusters, n):
    real_labels = []
    for i in range(0, num_clusters):
        top_cluster_names = get_top_names_in_cluster(i, labels, dataframe)
        real_labels.append(top_cluster_names[:n])
    return real_labels
    
#####################################################################################

min_max_scaler = preprocessing.MinMaxScaler()
#filter by gender 
main_df_merged_with_geo = main_df_merged_with_geo[main_df_merged_with_geo['gender'] == 'male']
geo_data = main_df_merged_with_geo[['LAT','LNG']]
geo_data['LAT'] = min_max_scaler.fit_transform(geo_data['LAT'].values.reshape(-1,1))
geo_data['LNG'] = min_max_scaler.fit_transform(geo_data['LNG'].values.reshape(-1,1))

latitude_list = geo_data['LAT'].tolist()
longitude_list = geo_data['LNG'].tolist()

vectors = []
for i in range(0,len(latitude_list)):
    vector = [latitude_list[i], longitude_list[i]]
    vectors.append(vector)
    
num_clusters = 5
kmeans = KMeans(init='k-means++', n_clusters=num_clusters, n_init=10)
kmeans.fit_predict(vectors)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_

 
real_labels = get_real_labels_for_clusters(labels, main_df_merged_with_geo, num_clusters, 2)
#real_labels = get_real_lables(labels, main_df_merged_with_geo, num_clusters, 1)
colors = ['red', 'green', 'purple', 'blue', 'orange']
print(real_labels)
plt.scatter(latitude_list, longitude_list, marker='o', c=labels, cmap=matplotlib.colors.ListedColormap(colors), s=100, edgecolor='k')
plt.legend(handles=create_patches(colors, real_labels), loc=4)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.show()
# Out:
# [[{'Everett ': 3}, {'Allston ': 2}], [{'Morton ': 4}, {'Hamilton ': 3}], [{'Tremont ': 6}, {'Condor ': 4}], [{'Parker ': 5}, {'Warren ': 4}], [{'Webster ': 5}, {'Grove ': 3}]]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
#filter by gender 
main_df_merged_with_geo = main_df_merged_with_geo[main_df_merged_with_geo['gender2'] == 'M']
geo_data = main_df_merged_with_geo[['LAT','LNG']]
geo_data['LAT'] = min_max_scaler.fit_transform(geo_data['LAT'].values.reshape(-1,1))
geo_data['LNG'] = min_max_scaler.fit_transform(geo_data['LNG'].values.reshape(-1,1))

latitude_list = geo_data['LAT'].tolist()
longitude_list = geo_data['LNG'].tolist()

vectors = []
for i in range(0,len(latitude_list)):
    vector = [latitude_list[i], longitude_list[i]]
    vectors.append(vector)
    
num_clusters = 5
kmeans = KMeans(init='k-means++', n_clusters=num_clusters, n_init=10)
kmeans.fit_predict(vectors)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_

 
real_labels = get_real_labels_for_clusters(labels, main_df_merged_with_geo, num_clusters, 2)
#real_labels = get_real_lables(labels, main_df_merged_with_geo, num_clusters, 1)
colors = ['red', 'green', 'purple', 'blue', 'orange']
print(real_labels)
plt.scatter(latitude_list, longitude_list, marker='o', c=labels, cmap=matplotlib.colors.ListedColormap(colors), s=100, edgecolor='k')
plt.legend(handles=create_patches(colors, real_labels), loc=4)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.show()
# Out:
# [[{'Tremont ': 6}, {'Condor ': 4}], [{'Parker ': 5}, {'Warren ': 4}], [{'Morton ': 4}, {'Hamilton ': 3}], [{'Webster ': 5}, {'Park ': 3}], [{'Everett ': 3}, {'Allston ': 2}]]

# %%
################################################################################################

def get_most_repetetive_names(dataframe, num_streets):
    dataframe['count'] = 1
    groupedByStreetNames = dataframe.groupby(['street-name'], sort=False)['count'].sum().to_frame()
    groupedByStreetNames = groupedByStreetNames.sort_values('count', ascending=False)
    #groupedByStreetNames = groupedByStreetNames.head(num_streets)
    count_dict = groupedByStreetNames.to_dict()
    return count_dict['count']

#####################################################################################################

def get_clusters_dict(cluster_labels, dataframe, count_dict):
    clusters_dict = {}
    labels_index = 0
    for index, row in main_df_merged_with_geo.iterrows():
        key = row['street-name']
        if key in clusters_dict:
            clusters_dict[key]['clusters-labels'].append(cluster_labels[labels_index])
            clusters_dict[key]['full-names'].append(row['full_name'])
        else:
            clusters_dict[key] = {}
            clusters_dict[key]['clusters-labels'] =[]
            clusters_dict[key]['clusters-labels'].append(cluster_labels[labels_index])
            clusters_dict[key]['full-names'] =[]
            clusters_dict[key]['full-names'].append(row['full_name'])
            clusters_dict[key]['gender'] = row['gender']
            clusters_dict[key]['gender2'] = row['gender2']
            clusters_dict[key]['global-frequency'] = count_dict[key]
            
        labels_index += 1 
    return clusters_dict

#######################################################################################################

def get_distribution_rank(clusters_dict, num_clusters):
    for street_name,clusters_labels in clusters_dict.items():
        clusters_dict[street_name]['distribution_rank'] = len(set(clusters_dict[street_name]['clusters-labels']))
        clusters_dict[street_name]['concentration_rank'] = get_max_clone_population(clusters_dict[street_name]['clusters-labels'], num_clusters)
    return clusters_dict

########################################################################################################

def get_max_clone_population(cluster_labels, num_clusters):
    clone_pop_dict = []
    for i in range(0, num_clusters):
        clone_pop_dict.append(0)
    for elem in cluster_labels:
        clone_pop_dict[elem] += 1
    return max(clone_pop_dict)

###########################################################################################################
count_dict = get_most_repetetive_names(df, 10)
clusters_dict = get_clusters_dict(labels, main_df_merged_with_geo, count_dict)
clusters_dict = get_distribution_rank(clusters_dict, num_clusters)
top_names_df = pd.DataFrame.from_dict(clusters_dict, orient='index')
top_names_df = top_names_df.sort_values(by=['concentration_rank'], ascending=False)
clone_list = top_names_df['concentration_rank'].tolist()
top_names_df
# Out:
#                                               clusters-labels  \
# Tremont                           [0, 0, 0, 0, 1, 4, 0, 2, 0]
# Webster                                 [0, 3, 0, 3, 3, 3, 3]
# Parker                                        [1, 1, 1, 1, 1]
# Harvard                     [1, 1, 3, 0, 0, 3, 0, 2, 4, 2, 0]
# Warren                         [1, 3, 3, 1, 0, 4, 1, 0, 0, 1]
# Union                                         [0, 4, 0, 0, 0]
# Washburn                             [0, 3, 3, 1, 1, 0, 0, 0]
# Condor                                           [0, 0, 0, 0]
# Morton                                  [0, 2, 2, 1, 3, 2, 2]
# Amory                                               [1, 1, 1]
# Williams                                         [1, 2, 2, 2]
# Putnam                                        [0, 0, 0, 1, 3]
# Hamilton                                         [2, 2, 2, 3]
# Richmond                                            [2, 2, 2]
# Arlington                                     [0, 0, 3, 0, 4]
# Rugg                                                [1, 1, 1]
# St. James                                           [1, 1, 1]
# Cottage                                          [3, 0, 0, 0]
# Sullivan                                            [0, 0, 0]
# North                                         [0, 0, 2, 1, 0]
# Park                                    [0, 0, 3, 2, 3, 2, 3]
# Eliot                                               [1, 1, 1]
# Central                                          [0, 3, 0, 0]
# Monument                                         [0, 2, 0, 0]
# Forest Hills                                        [1, 1, 1]
# Chestnut                             [4, 3, 1, 0, 3, 1, 1, 0]
# Concord                                             [0, 0, 0]
# Orchard                                          [2, 1, 2, 2]
# Lincoln                                    [0, 0, 3, 2, 0, 2]
# Everett                        [0, 4, 4, 4, 3, 3, 2, 1, 1, 0]
# ...                                                       ...
# Furbush                                                   [1]
# Fulton                                                 [0, 3]
# Fuller                                                    [2]
# Fruit                                                     [1]
# Fruean                                                    [0]
# Frost                                                     [2]
# Friend                                                    [2]
# Fresno                                                    [0]
# French Terrace                                            [3]
# French                                                    [1]
# Fremont                                                   [2]
# Freeport                                                  [2]
# Freeland                                                  [3]
# Frederick Douglass                                        [2]
# Frederick                                                 [1]
# Frazer                                                 [0, 3]
# Franklin Terrace                                          [1]
# Franklin Hill                                             [3]
# Franklin Garden                                           [2]
# Franklin Court                                            [1]
# Frankfort                                                 [0]
# Francis Parkman Drive                                     [3]
# Francis J. Murray Way                                     [1]
# Francis J. Mitchell Bridge                                [0]
# Francis G. Hanlon                                         [2]
# Francis B. Johnson                                        [1]
# Francis                                                   [0]
# Fox Point                                                 [3]
# Fox                                                       [2]
# Woodstock                                                 [1]
#
#                                                                    full-names  \
# Tremont                     [Tremont Place,, Tremont Place,, Tremont Place...
# Webster                     [Webster Avenue,, Webster Place,, Webster Squa...
# Parker                      [Parker Street,, Parker Street,, Parker Street...
# Harvard                     [Harvard Avenue,, Harvard Avenue,, Harvard Ave...
# Warren                      [Warren Avenue,, Warren Avenue,, Warren Avenue...
# Union                       [Union Avenue,, Union Square,, Union Street,, ...
# Washburn                    [Washburn Street,, Washburn Street,, Washburn ...
# Condor                      [Condor Street,, Condor Street,, Condor Street...
# Morton                      [Morton Place,, Morton Place,, Morton Place,, ...
# Amory                           [Amory Avenue,, Amory Street,, Amory Street,]
# Williams                    [Williams Avenue,, Williams Street,, Williams ...
# Putnam                      [Putnam Avenue,, Putnam Square,, Putnam Street...
# Hamilton                    [Hamilton Place,, Hamilton Place,, Hamilton St...
# Richmond                    [Richmond Place,, Richmond Street,, Richmond S...
# Arlington                   [Arlington Avenue,, Arlington Square,, Arlingt...
# Rugg                                     [Rugg Road,, Rugg Road,, Rugg Road,]
# St. James                   [St. James Avenue,, St. James Place,, St. Jame...
# Cottage                     [Cottage Place,, Cottage Road,, Cottage Street...
# Sullivan                    [Sullivan Street,, Sullivan Street,, Sullivan ...
# North                       [North Avenue,, North Avenue,, North Square,, ...
# Park                        [Park Place,, Park Street,, Park Street,, Park...
# Eliot                            [Eliot Place,, Eliot Street,, Eliot Street,]
# Central                     [Central Avenue,, Central Avenue,, Central Squ...
# Monument                    [Monument Avenue,, Monument Square,, Monument ...
# Forest Hills                [Forest Hills Avenue,, Forest Hills Square,, F...
# Chestnut                    [Chestnut Avenue,, Chestnut Place,, Chestnut P...
# Concord                     [Concord Place,, Concord Square,, Concord Stre...
# Orchard                     [Orchard Avenue,, Orchard Road,, Orchard Stree...
# Lincoln                     [Lincoln Place,, Lincoln Place,, Lincoln Stree...
# Everett                     [Everett Avenue,, Everett Place,, Everett Squa...
# ...                                                                       ...
# Furbush                                                       [Furbush Road,]
# Fulton                                        [Fulton Place,, Fulton Street,]
# Fuller                                                       [Fuller Street,]
# Fruit                                                         [Fruit Street,]
# Fruean                                                        [Fruean Place,]
# Frost                                                         [Frost Avenue,]
# Friend                                                       [Friend Street,]
# Fresno                                                       [Fresno Street,]
# French Terrace                                              [French Terrace,]
# French                                                       [French Street,]
# Fremont                                                     [Fremont Street,]
# Freeport                                                   [Freeport Street,]
# Freeland                                                   [Freeland Street,]
# Frederick Douglass                               [Frederick Douglass Square,]
# Frederick                                                 [Frederick Street,]
# Frazer                                       [Frazer Street,, Frazer Street,]
# Franklin Terrace                                          [Franklin Terrace,]
# Franklin Hill                                         [Franklin Hill Avenue,]
# Franklin Garden                                             [Franklin Garden]
# Franklin Court                                              [Franklin Court,]
# Frankfort                                                 [Frankfort Street,]
# Francis Parkman Drive                                [Francis Parkman Drive,]
# Francis J. Murray Way                                 [Francis J. Murray Way]
# Francis J. Mitchell Bridge                      [Francis J. Mitchell Bridge,]
# Francis G. Hanlon                                 [Francis G. Hanlon Square,]
# Francis B. Johnson                               [Francis B. Johnson Square,]
# Francis                                                     [Francis Street,]
# Fox Point                                                   [Fox Point Road,]
# Fox                                                             [Fox Street,]
# Woodstock                                                 [Woodstock Avenue,]
#
#                            gender gender2  global-frequency  \
# Tremont                      male       M                 5
# Webster                      male       M                 8
# Parker                       male       M                 3
# Harvard                      male       M                10
# Warren                       male       M                10
# Union                        male       M                 5
# Washburn                     male       M                 1
# Condor                       male       M                 1
# Morton                       male       M                 4
# Amory                        male       M                 2
# Williams                     male       M                 3
# Putnam                       male       M                 6
# Hamilton                     male       M                 3
# Richmond                     male       M                 3
# Arlington                    male       M                 5
# Rugg                         male       M                 1
# St. James                    male       M                 3
# Cottage                      male       M                 4
# Sullivan                     male       M                 2
# North                        male       M                 3
# Park                         male       M                 6
# Eliot                        male       M                 4
# Central                      male       M                 4
# Monument                     male       M                 4
# Forest Hills                 male       M                 3
# Chestnut                     male       M                 9
# Concord                      male       M                 4
# Orchard                      male       M                 4
# Lincoln                      male       M                 6
# Everett                      male       M                10
# ...                           ...     ...               ...
# Furbush                      male       M                 1
# Fulton                       male       M                 3
# Fuller                       male       M                 2
# Fruit                        male       M                 1
# Fruean                       male       M                 1
# Frost                        male       M                 1
# Friend                       male       M                 1
# Fresno                       male       M                 1
# French Terrace               male       M                 1
# French                       male       M                 1
# Fremont                      male       M                 1
# Freeport                     male       M                 1
# Freeland                     male       M                 1
# Frederick Douglass           male       M                 1
# Frederick                    male       M                 1
# Frazer                       male       M                 2
# Franklin Terrace             male       M                 1
# Franklin Hill                male       M                 1
# Franklin Garden              male       M                 1
# Franklin Court               male       M                 1
# Frankfort                    male       M                 1
# Francis Parkman Drive        male       M                 1
# Francis J. Murray Way        male       M                 1
# Francis J. Mitchell Bridge   male       M                 1
# Francis G. Hanlon            male       M                 1
# Francis B. Johnson           male       M                 1
# Francis                      male       M                 1
# Fox Point                    male       M                 1
# Fox                          male       M                 1
# Woodstock                    male       M                 1
#
#                             distribution_rank  concentration_rank
# Tremont                                     4                   6
# Webster                                     2                   5
# Parker                                      1                   5
# Harvard                                     5                   4
# Warren                                      4                   4
# Union                                       2                   4
# Washburn                                    3                   4
# Condor                                      1                   4
# Morton                                      4                   4
# Amory                                       1                   3
# Williams                                    2                   3
# Putnam                                      3                   3
# Hamilton                                    2                   3
# Richmond                                    1                   3
# Arlington                                   3                   3
# Rugg                                        1                   3
# St. James                                   1                   3
# Cottage                                     2                   3
# Sullivan                                    1                   3
# North                                       3                   3
# Park                                        3                   3
# Eliot                                       1                   3
# Central                                     2                   3
# Monument                                    2                   3
# Forest Hills                                1                   3
# Chestnut                                    4                   3
# Concord                                     1                   3
# Orchard                                     2                   3
# Lincoln                                     3                   3
# Everett                                     5                   3
# ...                                       ...                 ...
# Furbush                                     1                   1
# Fulton                                      2                   1
# Fuller                                      1                   1
# Fruit                                       1                   1
# Fruean                                      1                   1
# Frost                                       1                   1
# Friend                                      1                   1
# Fresno                                      1                   1
# French Terrace                              1                   1
# French                                      1                   1
# Fremont                                     1                   1
# Freeport                                    1                   1
# Freeland                                    1                   1
# Frederick Douglass                          1                   1
# Frederick                                   1                   1
# Frazer                                      2                   1
# Franklin Terrace                            1                   1
# Franklin Hill                               1                   1
# Franklin Garden                             1                   1
# Franklin Court                              1                   1
# Frankfort                                   1                   1
# Francis Parkman Drive                       1                   1
# Francis J. Murray Way                       1                   1
# Francis J. Mitchell Bridge                  1                   1
# Francis G. Hanlon                           1                   1
# Francis B. Johnson                          1                   1
# Francis                                     1                   1
# Fox Point                                   1                   1
# Fox                                         1                   1
# Woodstock                                   1                   1
#
# [2202 rows x 7 columns]
